# %% [markdown]
# **实验目标：**
#
# 通过本实验，你将深入了解和实践说话人识别技术，并掌握利用声音特征进行有效说话人识别的基本方法，了解不同特征和模型对识别准确率的影响。
#
# 实验的核心目标是使用TIMIT数据集来训练一个说话人识别系统，涵盖数据预处理、特征提取、模型训练和评估等关键步骤。
#
#
# **实验方法：**
#
# **1. 数据预处理和划分(可选)：**
#   - 数据集下载地址（4月17日前有效）：https://f.ws59.cn/f/du8yd2536vl
#   - 为了方便大家，我们提供了划分好的TIMIT数据集结构，当然你也可以根据需求自行划分该数据集。
#   - 为简化难度，我们排除了SA的两个方言句子，并在剩余的8个句子中选取了SX的5个句子和SI的1个句子作为训练集，SI的另外2个句子作为测试集。
#   - 该链接下载的数据集只保留了音频文件，完整数据集（包含音频对应文本、标注等信息）可参见备注链接下载。
#
# **2. 特征提取：**
#   - 学习并实现包括但不限于MFCC特征等特征的提取，探索声音信号的频率和时间特性。
#   - 鼓励尝试和比较其他特征提取方法，例如LPCC或声谱图特征，以理解不同特征对识别性能的影响。
#
# **3. 模型选择和训练：**
#   - 探索并选择适合的分类器和模型进行说话人识别，如GMM、Softmax分类器或深度学习模型。
#   - 实现模型训练流程，使用训练集数据训练模型。
#
# **4. 评估和分析：**
#   - 使用准确率作为主要的评价指标在测试集上评估模型性能。
#   - 对比不同特征和模型的性能，分析其对说话人识别准确率的影响。
#   - 可视化不同模型的识别结果和错误率，讨论可能的改进方法。
#
# **实验要求：**
#   - 1.选择并实现至少一种特征的提取，并鼓励尝试其他特征提取方法。
#   - 2.选择并实现至少一种分类器或模型进行说话人识别，并使用准确率评估指标评估其性能。
#   - 3.通过实验对比、分析和可视化，撰写详细的实验报告，包括实验目的、实验方法、结果分析和结论。
#   - 4.实验报告应以清晰、逻辑性强的形式呈现，图表和结果应清楚明了。
#
# **其他说明：**
#   - 实验的最终打分环节会看识别性能，会对原理和实现代码部分做抽查提问，综合评定成绩。
#   - 我们**鼓励做原创性探索**，即使性能不是很好，但有创新性、有价值、有意义的探索和尝试会有额外加分。
#   - 原数完整据集下载地址：https://drive.google.com/file/d/180mSIiXN9RVDV2Xn1xcWNkMRm5J5MjN4/view?usp=sharing \
#     或国内访问地址（4月17日前有效）：https://f.ws59.cn/f/du8xu130kba

# %% [markdown]
# ## 1. 实验准备

# %%
# 1. 导入必要的库
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. 数据预处理

# %%
# 2. 数据预处理
def load_json_data(json_file):
    """加载JSON格式的数据集"""
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

# 加载训练集和测试集
train_data = load_json_data('trainset.json')
test_data = load_json_data('testset.json')

# %% [markdown]
# - 数据集信息展示

# %%
# 打印数据集信息
print(f"训练集样本数: {len(train_data)}")
print(f"测试集样本数: {len(test_data)}")

# 查看数据样例
print("\n训练集样例:")
print(train_data[0])

# 统计说话人和方言区域的分布
train_speakers = set([item['speaker_id'] for item in train_data])
test_speakers = set([item['speaker_id'] for item in test_data])
train_dialects = set([item['dialect_region'] for item in train_data])

print(f"\n训练集包含 {len(train_speakers)} 位说话人")
print(f"测试集包含 {len(test_speakers)} 位说话人")
print(f"数据集包含 {len(train_dialects)} 个方言区域")

# 创建说话人ID到索引的映射
all_speakers = sorted(list(train_speakers.union(test_speakers)))
speaker_to_idx = {speaker: idx for idx, speaker in enumerate(all_speakers)}
idx_to_speaker = {idx: speaker for speaker, idx in speaker_to_idx.items()}

print(f"\n共有 {len(speaker_to_idx)} 位说话人")
# Out:
# 训练集样本数: 2772
# 测试集样本数: 924
#
# 训练集样例:
# {'audio_filepath': './Dataset/TRAIN/DR1/FCJF0/SI648_.wav', 'dialect_region': 'DR1', 'gender': 'F', 'speaker_id': 'CJF0'}
#
# 训练集包含 462 位说话人
# 测试集包含 462 位说话人
# 数据集包含 8 个方言区域
#
# 共有 462 位说话人

# %% [markdown]
# - 数据集信息可视化

# %%
# 可视化数据集中的音频样本分布
train_gender_counts = {"F": 0, "M": 0}
for item in train_data:
    train_gender_counts[item['gender']] += 1

plt.figure(figsize=(10, 5))
plt.bar(train_gender_counts.keys(), train_gender_counts.values())
plt.title('训练集中男女说话人的样本分布')
plt.xlabel('性别')
plt.ylabel('样本数量')
plt.show()

# 可视化一个音频样本的波形
def plot_audio_sample(audio_path):
    """绘制音频波形和频谱图"""
    y, sr = librosa.load(audio_path, sr=None)
    
    plt.rcParams['font.family'] = 'STFangsong'
    plt.figure(figsize=(12, 8))
    
    # 波形图
    plt.subplot(2, 1, 1)
    librosa.display.waveshow(y, sr=sr)
    plt.title('波形图')
    
    # 频谱图
    plt.subplot(2, 1, 2)
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title('频谱图')
    
    plt.tight_layout()
    plt.show()

# 展示一个样本的波形和频谱，以确认加载成功
if len(train_data) > 0:
    sample_path = train_data[0]['audio_filepath']
    print(f"\n显示样本音频: {sample_path}")
    plot_audio_sample(sample_path)
# Out:
# 显示样本音频: ./Dataset/TRAIN/DR1/FCJF0/SI648_.wav

# %% [markdown]
# ## 3. 特征提取 —— LPCC （Linear Prediction Cepstral Coefficients，线性预测倒谱系数）<br>
# 基本思想是通过线性预测（LPC）建模语音信号的谱包络，再将其转换为倒谱系数（Cepstral Coefficients），从而获得更加稳健、紧凑的语音特征表示。<br>

# %%
# 3. 特征提取 - LPCC (Linear Prediction Cepstral Coefficients)
def extract_lpcc_features(audio_path, n_lpcc=20, pre_emphasis=0.97, n_fft=2048, win_length=0.025, hop_length=0.01):
    """
    从音频文件中提取LPCC特征
    
    参数:
    audio_path: 音频文件路径
    n_lpcc: LPCC系数数量
    pre_emphasis: 预加重因子
    n_fft: FFT大小
    win_length: 窗口长度(秒)
    hop_length: 窗口移动步长(秒)
    
    返回:
    lpcc: LPCC特征矩阵 (时间帧数 × LPCC系数数)
    """
    # 加载音频
    y, sr = librosa.load(audio_path, sr=None)
    
    # 预加重处理
    y = np.append(y[0], y[1:] - pre_emphasis * y[:-1])
    
    # 转换窗口长度和步长从秒到样本数
    win_length_samples = int(win_length * sr)
    hop_length_samples = int(hop_length * sr)
    
    # 分帧和加窗
    frames = librosa.util.frame(y, frame_length=win_length_samples, hop_length=hop_length_samples)
    
    # 应用汉明窗
    window = np.hamming(win_length_samples)
    windowed_frames = frames.T * window
    
    # 逐帧提取LPC系数
    lpc_coeffs = []
    for frame in windowed_frames:
        a = librosa.lpc(frame, order=n_lpcc)
        lpc_coeffs.append(a)
    
    lpc_coeffs = np.array(lpc_coeffs)
    
    # 将LPC系数转换为LPCC系数
    lpcc_features = []
    for i in range(len(lpc_coeffs)):
        a = lpc_coeffs[i]
        lpcc = [0] * n_lpcc
        
        # 第一个LPCC系数
        lpcc[0] = -np.log(a[0])
        
        # 剩余的LPCC系数
        for n in range(1, min(n_lpcc, len(a) - 1)):
            lpcc[n] = a[n]
            for k in range(1, n):
                lpcc[n] += a[k] * lpcc[n-k] * (n-k) / n
            lpcc[n] = -lpcc[n]
            
        lpcc_features.append(lpcc)
    
    return np.array(lpcc_features)



# 可视化LPCC特征
def visualize_lpcc(lpcc, title="LPCC特征"):
    """可视化LPCC特征矩阵"""
    plt.figure(figsize=(12, 6))
    librosa.display.specshow(lpcc.T, x_axis='time')
    plt.colorbar()
    plt.title(title)
    plt.tight_layout()
    plt.show()

# 为训练集和测试集提取LPCC特征
def prepare_lpcc_features_for_gmm(data, n_lpcc=20):
    """
    为GMM模型准备LPCC特征集和标签集
    
    返回:
    features_dict: 按说话人ID组织的特征字典
    """
    features_dict = {}
    
    for item in data:
        speaker_id = item['speaker_id']
        
        if speaker_id not in features_dict:
            features_dict[speaker_id] = []
        
        # 提取特征
        lpcc = extract_lpcc_features(item['audio_filepath'], n_lpcc)
        features_dict[speaker_id].append(lpcc)
    
    # 合并每个说话人的所有特征
    for speaker_id in features_dict:
        features_dict[speaker_id] = np.vstack(features_dict[speaker_id])
    
    return features_dict

# %%
# 使用训练集样本可视化LPCC特征
if len(train_data) > 0:
    sample_path = train_data[0]['audio_filepath']
    sample_speaker = train_data[0]['speaker_id']
    
    # 提取并显示LPCC特征
    lpcc = extract_lpcc_features(sample_path)
    visualize_lpcc(lpcc, f"说话人 {sample_speaker} 的LPCC特征")

print("正在为训练集提取LPCC特征...")
train_features_dict = prepare_lpcc_features_for_gmm(train_data)

print("正在为测试集提取LPCC特征...")
test_features_dict = prepare_lpcc_features_for_gmm(test_data)

print("LPCC特征提取完成!")
# Out:
# 正在为训练集提取LPCC特征...
# 正在为测试集提取LPCC特征...
# LPCC特征提取完成!

# %% [markdown]
# - LPCC特征图图像解读：
# - 时序结构<br>
# 横向连续的模式（类似条纹、波动）表示语音的时间动态变化。可用于观察说话过程中的停顿、发音强弱、语速变化等。<br>
# - LPCC维度<br>
# 低维系数（图下方）通常对应语音的包络轮廓（共振峰），反映说话人口腔、喉部形状。高维系数（图上方）往往更受高频噪声干扰，因此变化较乱、信息密度较低。<br>
# - 颜色分布<br>
# 深红色：表示该维度在此帧中有强烈响应（可能是重要语音特征或个体发声特性）。
# 深蓝色：可能表示共振空白、静音、噪声干扰或个体独特特征的负响应。
# 浅色：表示该特征分量较弱。

# %% [markdown]
# ## 4. 模型选择和训练 - GMM (Gaussian Mixture Model)

# %%
from sklearn.mixture import GaussianMixture
def train_gmm_per_speaker(features_dict, n_components=8):
    """
    为每位说话人训练独立的GMM模型
    
    参数:
    features_dict: 按说话人ID组织的特征字典
    n_components: 高斯混合成分数量
    
    返回:
    gmms: 以说话人ID为键，GMM模型为值的字典
    """
    gmms = {}
    
    for speaker_id, features in features_dict.items():
        print(f"训练说话人 {speaker_id} 的GMM模型...")
        
        # 创建并训练GMM模型
        gmm = GaussianMixture(
            n_components=n_components,
            covariance_type='diag',  # 使用对角协方差矩阵
            max_iter=200,
            random_state=42
        )
        
        gmm.fit(features)
        gmms[speaker_id] = gmm
    
    return gmms

# %%
# 训练GMM模型
print("开始基于LPCC特征的GMM模型训练...")
n_components = 8  # 高斯混合成分数量
lpcc_gmm_models = train_gmm_per_speaker(train_features_dict, n_components)
print("LPCC-GMM模型训练完成!")
# Out:
# 开始基于LPCC特征的GMM模型训练...
# 训练说话人 CJF0 的GMM模型...
# 训练说话人 DAW0 的GMM模型...
# 训练说话人 DML0 的GMM模型...
# 训练说话人 ECD0 的GMM模型...
# 训练说话人 ETB0 的GMM模型...
# 训练说话人 JSP0 的GMM模型...
# 训练说话人 KFB0 的GMM模型...
# 训练说话人 MEM0 的GMM模型...
# 训练说话人 SAH0 的GMM模型...
# 训练说话人 SJK1 的GMM模型...
# 训练说话人 SMA0 的GMM模型...
# 训练说话人 TBR0 的GMM模型...
# 训练说话人 VFB0 的GMM模型...
# 训练说话人 VMH0 的GMM模型...
# 训练说话人 CPM0 的GMM模型...
# 训练说话人 DAC0 的GMM模型...
# 训练说话人 DPK0 的GMM模型...
# 训练说话人 EDR0 的GMM模型...
# 训练说话人 GRL0 的GMM模型...
# 训练说话人 JEB1 的GMM模型...
# 训练说话人 JWT0 的GMM模型...
# 训练说话人 KLS0 的GMM模型...
# 训练说话人 KLW0 的GMM模型...
# 训练说话人 MGG0 的GMM模型...
# 训练说话人 MRP0 的GMM模型...
# 训练说话人 PGH0 的GMM模型...
# 训练说话人 PGR0 的GMM模型...
# 训练说话人 PSW0 的GMM模型...
# 训练说话人 RAI0 的GMM模型...
# 训练说话人 RCG0 的GMM模型...
# 训练说话人 RDD0 的GMM模型...
# 训练说话人 RSO0 的GMM模型...
# 训练说话人 RWS0 的GMM模型...
# 训练说话人 TJS0 的GMM模型...
# 训练说话人 TPF0 的GMM模型...
# 训练说话人 TRR0 的GMM模型...
# 训练说话人 WAD0 的GMM模型...
# 训练说话人 WAR0 的GMM模型...
# 训练说话人 AEM0 的GMM模型...
# 训练说话人 AJW0 的GMM模型...
# 训练说话人 CAJ0 的GMM模型...
# 训练说话人 CMM0 的GMM模型...
# 训练说话人 CYL0 的GMM模型...
# 训练说话人 DAS1 的GMM模型...
# 训练说话人 DNC0 的GMM模型...
# 训练说话人 DXW0 的GMM模型...
# 训练说话人 EAC0 的GMM模型...
# 训练说话人 HLM0 的GMM模型...
# 训练说话人 JKL0 的GMM模型...
# 训练说话人 KAA0 的GMM模型...
# 训练说话人 LMA0 的GMM模型...
# 训练说话人 LMC0 的GMM模型...
# 训练说话人 MJB0 的GMM模型...
# 训练说话人 MKF0 的GMM模型...
# 训练说话人 MMH0 的GMM模型...
# 训练说话人 PJF0 的GMM模型...
# 训练说话人 RLL0 的GMM模型...
# 训练说话人 SCN0 的GMM模型...
# 训练说话人 SKL0 的GMM模型...
# 训练说话人 SRH0 的GMM模型...
# 训练说话人 TMG0 的GMM模型...
# 训练说话人 ARC0 的GMM模型...
# 训练说话人 BJV0 的GMM模型...
# 训练说话人 CEW0 的GMM模型...
# 训练说话人 CTM0 的GMM模型...
# 训练说话人 DBP0 的GMM模型...
# 训练说话人 DEM0 的GMM模型...
# 训练说话人 DLB0 的GMM模型...
# 训练说话人 DLC2 的GMM模型...
# 训练说话人 DMT0 的GMM模型...
# 训练说话人 DPS0 的GMM模型...
# 训练说话人 DSS0 的GMM模型...
# 训练说话人 DWD0 的GMM模型...
# 训练说话人 EFG0 的GMM模型...
# 训练说话人 HRM0 的GMM模型...
# 训练说话人 JAE0 的GMM模型...
# 训练说话人 JBG0 的GMM模型...
# 训练说话人 JDE0 的GMM模型...
# 训练说话人 JEB0 的GMM模型...
# 训练说话人 JHI0 的GMM模型...
# 训练说话人 JMA0 的GMM模型...
# 训练说话人 JMD0 的GMM模型...
# 训练说话人 JPM0 的GMM模型...
# 训练说话人 JRP0 的GMM模型...
# 训练说话人 KAH0 的GMM模型...
# 训练说话人 KAJ0 的GMM模型...
# 训练说话人 KDT0 的GMM模型...
# 训练说话人 KJO0 的GMM模型...
# 训练说话人 MAA0 的GMM模型...
# 训练说话人 MAG0 的GMM模型...
# 训练说话人 MDS0 的GMM模型...
# 训练说话人 MGK0 的GMM模型...
# 训练说话人 MXS0 的GMM模型...
# 训练说话人 PPC0 的GMM模型...
# 训练说话人 PRB0 的GMM模型...
# 训练说话人 RAB0 的GMM模型...
# 训练说话人 RCW0 的GMM模型...
# 训练说话人 RFK0 的GMM模型...
# 训练说话人 RGS0 的GMM模型...
# 训练说话人 RHL0 的GMM模型...
# 训练说话人 RJH0 的GMM模型...
# 训练说话人 RJM0 的GMM模型...
# 训练说话人 RJM1 的GMM模型...
# 训练说话人 RJT0 的GMM模型...
# 训练说话人 RLJ0 的GMM模型...
# 训练说话人 RLR0 的GMM模型...
# 训练说话人 RMS0 的GMM模型...
# 训练说话人 SAT0 的GMM模型...
# 训练说话人 TAT1 的GMM模型...
# 训练说话人 TBC0 的GMM模型...
# 训练说话人 TDB0 的GMM模型...
# 训练说话人 TJG0 的GMM模型...
# 训练说话人 WSB0 的GMM模型...
# 训练说话人 ZMB0 的GMM模型...
# 训练说话人 ALK0 的GMM模型...
# 训练说话人 CKE0 的GMM模型...
# 训练说话人 CMG0 的GMM模型...
# 训练说话人 DFB0 的GMM模型...
# 训练说话人 DJH0 的GMM模型...
# 训练说话人 EME0 的GMM模型...
# 训练说话人 GCS0 的GMM模型...
# 训练说话人 GRW0 的GMM模型...
# 训练说话人 JLG0 的GMM模型...
# 训练说话人 JLR0 的GMM模型...
# 训练说话人 LAC0 的GMM模型...
# 训练说话人 LJD0 的GMM模型...
# 训练说话人 LTM0 的GMM模型...
# 训练说话人 MJF0 的GMM模型...
# 训练说话人 NTB0 的GMM模型...
# 训练说话人 PAZ0 的GMM模型...
# 训练说话人 SJS0 的GMM模型...
# 训练说话人 SJW0 的GMM模型...
# 训练说话人 SKC0 的GMM模型...
# 训练说话人 SLS0 的GMM模型...
# 训练说话人 ADC0 的GMM模型...
# 训练说话人 AKB0 的GMM模型...
# 训练说话人 AKR0 的GMM模型...
# 训练说话人 APV0 的GMM模型...
# 训练说话人 BEF0 的GMM模型...
# 训练说话人 CAL0 的GMM模型...
# 训练说话人 CDC0 的GMM模型...
# 训练说话人 CDD0 的GMM模型...
# 训练说话人 CEF0 的GMM模型...
# 训练说话人 DBB1 的GMM模型...
# 训练说话人 DDC0 的GMM模型...
# 训练说话人 DEF0 的GMM模型...
# 训练说话人 DHS0 的GMM模型...
# 训练说话人 DJM0 的GMM模型...
# 训练说话人 DLC0 的GMM模型...
# 训练说话人 DLH0 的GMM模型...
# 训练说话人 DNS0 的GMM模型...
# 训练说话人 DSS1 的GMM模型...
# 训练说话人 DTB0 的GMM模型...
# 训练说话人 DWM0 的GMM模型...
# 训练说话人 FMC0 的GMM模型...
# 训练说话人 GAF0 的GMM模型...
# 训练说话人 HJB0 的GMM模型...
# 训练说话人 HMR0 的GMM模型...
# 训练说话人 ILB0 的GMM模型...
# 训练说话人 JDA0 的GMM模型...
# 训练说话人 JJB0 的GMM模型...
# 训练说话人 JKR0 的GMM模型...
# 训练说话人 JLG1 的GMM模型...
# 训练说话人 JRH1 的GMM模型...
# 训练说话人 KLS1 的GMM模型...
# 训练说话人 KXL0 的GMM模型...
# 训练说话人 LNS0 的GMM模型...
# 训练说话人 MAM0 的GMM模型...
# 训练说话人 MAR0 的GMM模型...
# 训练说话人 MEB0 的GMM模型...
# 训练说话人 MJB1 的GMM模型...
# 训练说话人 MSM0 的GMM模型...
# 训练说话人 PRD0 的GMM模型...
# 训练说话人 RBC0 的GMM模型...
# 训练说话人 RDS0 的GMM模型...
# 训练说话人 REE0 的GMM模型...
# 训练说话人 REH1 的GMM模型...
# 训练说话人 RJB1 的GMM模型...
# 训练说话人 RTC0 的GMM模型...
# 训练说话人 RTJ0 的GMM模型...
# 训练说话人 RWA0 的GMM模型...
# 训练说话人 SFV0 的GMM模型...
# 训练说话人 TJM0 的GMM模型...
# 训练说话人 TKP0 的GMM模型...
# 训练说话人 TLB0 的GMM模型...
# 训练说话人 TPG0 的GMM模型...
# 训练说话人 TPP0 的GMM模型...
# 训练说话人 VJH0 的GMM模型...
# 训练说话人 WDK0 的GMM模型...
# 训练说话人 WGR0 的GMM模型...
# 训练说话人 ALR0 的GMM模型...
# 训练说话人 BAS0 的GMM模型...
# 训练说话人 BMJ0 的GMM模型...
# 训练说话人 CAG0 的GMM模型...
# 训练说话人 DKN0 的GMM模型...
# 训练说话人 EEH0 的GMM模型...
# 训练说话人 JWB1 的GMM模型...
# 训练说话人 JXP0 的GMM模型...
# 训练说话人 KDW0 的GMM模型...
# 训练说话人 KLC0 的GMM模型...
# 训练说话人 LHD0 的GMM模型...
# 训练说话人 LKM0 的GMM模型...
# 训练说话人 PAF0 的GMM模型...
# 训练说话人 SAK0 的GMM模型...
# 训练说话人 SSB0 的GMM模型...
# 训练说话人 AEB0 的GMM模型...
# 训练说话人 ARW0 的GMM模型...
# 训练说话人 BMA0 的GMM模型...
# 训练说话人 BWP0 的GMM模型...
# 训练说话人 CDR0 的GMM模型...
# 训练说话人 CSS0 的GMM模型...
# 训练说话人 DCD0 的GMM模型...
# 训练说话人 DMA0 的GMM模型...
# 训练说话人 ESG0 的GMM模型...
# 训练说话人 FRM0 的GMM模型...
# 训练说话人 FWK0 的GMM模型...
# 训练说话人 GAG0 的GMM模型...
# 训练说话人 GJC0 的GMM模型...
# 训练说话人 GRP0 的GMM模型...
# 训练说话人 GXP0 的GMM模型...
# 训练说话人 JAC0 的GMM模型...
# 训练说话人 JDC0 的GMM模型...
# 训练说话人 JEE0 的GMM模型...
# 训练说话人 JJJ0 的GMM模型...
# 训练说话人 JLB0 的GMM模型...
# 训练说话人 JLS0 的GMM模型...
# 训练说话人 JMM0 的GMM模型...
# 训练说话人 JPM1 的GMM模型...
# 训练说话人 JRH0 的GMM模型...
# 训练说话人 JSR0 的GMM模型...
# 训练说话人 JWS0 的GMM模型...
# 训练说话人 JXL0 的GMM模型...
# 训练说话人 KAM0 的GMM模型...
# 训练说话人 LBC0 的GMM模型...
# 训练说话人 LEL0 的GMM模型...
# 训练说话人 LJC0 的GMM模型...
# 训练说话人 LJH0 的GMM模型...
# 训练说话人 LSH0 的GMM模型...
# 训练说话人 MBS0 的GMM模型...
# 训练说话人 MDM0 的GMM模型...
# 训练说话人 MGC0 的GMM模型...
# 训练说话人 NET0 的GMM模型...
# 训练说话人 PEB0 的GMM模型...
# 训练说话人 PRK0 的GMM模型...
# 训练说话人 PRT0 的GMM模型...
# 训练说话人 RAB1 的GMM模型...
# 训练说话人 RFL0 的GMM模型...
# 训练说话人 RGM0 的GMM模型...
# 训练说话人 RSP0 的GMM模型...
# 训练说话人 SFH0 的GMM模型...
# 训练说话人 SMC0 的GMM模型...
# 训练说话人 SMS0 的GMM模型...
# 训练说话人 SRG0 的GMM模型...
# 训练说话人 STF0 的GMM模型...
# 训练说话人 TAS0 的GMM模型...
# 训练说话人 TQC0 的GMM模型...
# 训练说话人 TRC0 的GMM模型...
# 训练说话人 TRT0 的GMM模型...
# 训练说话人 BJL0 的GMM模型...
# 训练说话人 BMH0 的GMM模型...
# 训练说话人 CDR1 的GMM模型...
# 训练说话人 DMY0 的GMM模型...
# 训练说话人 DTD0 的GMM模型...
# 训练说话人 EAR0 的GMM模型...
# 训练说话人 EXM0 的GMM模型...
# 训练说话人 GDP0 的GMM模型...
# 训练说话人 GMB0 的GMM模型...
# 训练说话人 JXM0 的GMM模型...
# 训练说话人 KKH0 的GMM模型...
# 训练说话人 LJA0 的GMM模型...
# 训练说话人 LJG0 的GMM模型...
# 训练说话人 LMK0 的GMM模型...
# 训练说话人 LOD0 的GMM模型...
# 训练说话人 MPG0 的GMM模型...
# 训练说话人 PMY0 的GMM模型...
# 训练说话人 SAG0 的GMM模型...
# 训练说话人 SDC0 的GMM模型...
# 训练说话人 SJG0 的GMM模型...
# 训练说话人 SKP0 的GMM模型...
# 训练说话人 SMM0 的GMM模型...
# 训练说话人 SMS1 的GMM模型...
# 训练说话人 TBW0 的GMM模型...
# 训练说话人 TLG0 的GMM模型...
# 训练说话人 BGT0 的GMM模型...
# 训练说话人 CHL0 的GMM模型...
# 训练说话人 CLM0 的GMM模型...
# 训练说话人 DAS0 的GMM模型...
# 训练说话人 DHL0 的GMM模型...
# 训练说话人 DSJ0 的GMM模型...
# 训练说话人 DWH0 的GMM模型...
# 训练说话人 EGJ0 的GMM模型...
# 训练说话人 EWM0 的GMM模型...
# 训练说话人 FER0 的GMM模型...
# 训练说话人 GES0 的GMM模型...
# 训练说话人 GSH0 的GMM模型...
# 训练说话人 HIT0 的GMM模型...
# 训练说话人 HMG0 的GMM模型...
# 训练说话人 JDM0 的GMM模型...
# 训练说话人 JFH0 的GMM模型...
# 训练说话人 JPG0 的GMM模型...
# 训练说话人 JRG0 的GMM模型...
# 训练说话人 JWG0 的GMM模型...
# 训练说话人 JXA0 的GMM模型...
# 训练说话人 MAB1 的GMM模型...
# 训练说话人 MCC0 的GMM模型...
# 训练说话人 MDM1 的GMM模型...
# 训练说话人 MVP0 的GMM模型...
# 训练说话人 MWB0 的GMM模型...
# 训练说话人 PMB0 的GMM模型...
# 训练说话人 RAM0 的GMM模型...
# 训练说话人 RAV0 的GMM模型...
# 训练说话人 REW1 的GMM模型...
# 训练说话人 RKM0 的GMM模型...
# 训练说话人 RLD0 的GMM模型...
# 训练说话人 RML0 的GMM模型...
# 训练说话人 RVG0 的GMM模型...
# 训练说话人 SAS0 的GMM模型...
# 训练说话人 SDH0 的GMM模型...
# 训练说话人 SEM1 的GMM模型...
# 训练说话人 SRR0 的GMM模型...
# 训练说话人 TAT0 的GMM模型...
# 训练说话人 TDP0 的GMM模型...
# 训练说话人 TMT0 的GMM模型...
# 训练说话人 VLO0 的GMM模型...
# 训练说话人 WAC0 的GMM模型...
# 训练说话人 WCH0 的GMM模型...
# 训练说话人 WEM0 的GMM模型...
# 训练说话人 WSH0 的GMM模型...
# 训练说话人 APB0 的GMM模型...
# 训练说话人 BCH0 的GMM模型...
# 训练说话人 HXS0 的GMM模型...
# 训练说话人 JDM2 的GMM模型...
# 训练说话人 KLC1 的GMM模型...
# 训练说话人 LAG0 的GMM模型...
# 训练说话人 MJU0 的GMM模型...
# 训练说话人 PAD0 的GMM模型...
# 训练说话人 RJB0 的GMM模型...
# 训练说话人 SBK0 的GMM模型...
# 训练说话人 SDJ0 的GMM模型...
# 训练说话人 SGF0 的GMM模型...
# 训练说话人 TAJ0 的GMM模型...
# 训练说话人 ABC0 的GMM模型...
# 训练说话人 AJP0 的GMM模型...
# 训练说话人 BMA1 的GMM模型...
# 训练说话人 CAE0 的GMM模型...
# 训练说话人 DRD0 的GMM模型...
# 训练说话人 EAL0 的GMM模型...
# 训练说话人 EJL0 的GMM模型...
# 训练说话人 ESJ0 的GMM模型...
# 训练说话人 JRK0 的GMM模型...
# 训练说话人 KES0 的GMM模型...
# 训练说话人 KLN0 的GMM模型...
# 训练说话人 MDB0 的GMM模型...
# 训练说话人 PGR1 的GMM模型...
# 训练说话人 RMB0 的GMM模型...
# 训练说话人 RXB0 的GMM模型...
# 训练说话人 SAT1 的GMM模型...
# 训练说话人 SDS0 的GMM模型...
# 训练说话人 SJK0 的GMM模型...
# 训练说话人 SMR0 的GMM模型...
# 训练说话人 SVS0 的GMM模型...
# 训练说话人 TJU0 的GMM模型...
# 训练说话人 TXS0 的GMM模型...
# 训练说话人 BLV0 的GMM模型...
# 训练说话人 CJS0 的GMM模型...
# 训练说话人 CRZ0 的GMM模型...
# 训练说话人 JEN0 的GMM模型...
# 训练说话人 JHK0 的GMM模型...
# 训练说话人 JRP1 的GMM模型...
# 训练说话人 JSK0 的GMM模型...
# 训练说话人 KDE0 的GMM模型...
# 训练说话人 KSR0 的GMM模型...
# 训练说话人 LEH0 的GMM模型...
# 训练说话人 LET0 的GMM模型...
# 训练说话人 MAH1 的GMM模型...
# 训练说话人 MKC0 的GMM模型...
# 训练说话人 PAB1 的GMM模型...
# 训练说话人 PAC0 的GMM模型...
# 训练说话人 REH0 的GMM模型...
# 训练说话人 SPM0 的GMM模型...
# 训练说话人 VKB0 的GMM模型...
# 训练说话人 ADD0 的GMM模型...
# 训练说话人 AEO0 的GMM模型...
# 训练说话人 AFM0 的GMM模型...
# 训练说话人 BAR0 的GMM模型...
# 训练说话人 BBR0 的GMM模型...
# 训练说话人 BML0 的GMM模型...
# 训练说话人 BOM0 的GMM模型...
# 训练说话人 BTH0 的GMM模型...
# 训练说话人 CLK0 的GMM模型...
# 训练说话人 CRE0 的GMM模型...
# 训练说话人 CTH0 的GMM模型...
# 训练说话人 DCM0 的GMM模型...
# 训练说话人 DED0 的GMM模型...
# 训练说话人 DKS0 的GMM模型...
# 训练说话人 DLC1 的GMM模型...
# 训练说话人 DLM0 的GMM模型...
# 训练说话人 DLR0 的GMM模型...
# 训练说话人 DLR1 的GMM模型...
# 训练说话人 DPB0 的GMM模型...
# 训练说话人 FXS0 的GMM模型...
# 训练说话人 FXV0 的GMM模型...
# 训练说话人 GAK0 的GMM模型...
# 训练说话人 GAR0 的GMM模型...
# 训练说话人 GAW0 的GMM模型...
# 训练说话人 GSL0 的GMM模型...
# 训练说话人 HBS0 的GMM模型...
# 训练说话人 HXL0 的GMM模型...
# 训练说话人 JAI0 的GMM模型...
# 训练说话人 JDG0 的GMM模型...
# 训练说话人 JFR0 的GMM模型...
# 训练说话人 JJM0 的GMM模型...
# 训练说话人 JRA0 的GMM模型...
# 训练说话人 KAG0 的GMM模型...
# 训练说话人 KDB0 的GMM模型...
# 训练说话人 KLR0 的GMM模型...
# 训练说话人 MDG0 的GMM模型...
# 训练说话人 MWS1 的GMM模型...
# 训练说话人 NTW0 的GMM模型...
# 训练说话人 PAR0 的GMM模型...
# 训练说话人 PFU0 的GMM模型...
# 训练说话人 REM0 的GMM模型...
# 训练说话人 RLJ1 的GMM模型...
# 训练说话人 RMG0 的GMM模型...
# 训练说话人 RMH0 的GMM模型...
# 训练说话人 RPC1 的GMM模型...
# 训练说话人 SAH1 的GMM模型...
# 训练说话人 SDB0 的GMM模型...
# 训练说话人 SES0 的GMM模型...
# 训练说话人 TAB0 的GMM模型...
# 训练说话人 TER0 的GMM模型...
# 训练说话人 TKD0 的GMM模型...
# 训练说话人 TLC0 的GMM模型...
# 训练说话人 TML0 的GMM模型...
# 训练说话人 TMN0 的GMM模型...
# 训练说话人 TPR0 的GMM模型...
# 训练说话人 TWH1 的GMM模型...
# 训练说话人 VRW0 的GMM模型...
# 训练说话人 WRE0 的GMM模型...
# 训练说话人 WRP0 的GMM模型...
# 训练说话人 BCG1 的GMM模型...
# 训练说话人 CEG0 的GMM模型...
# 训练说话人 CLT0 的GMM模型...
# 训练说话人 JRB0 的GMM模型...
# 训练说话人 KLH0 的GMM模型...
# 训练说话人 MBG0 的GMM模型...
# 训练说话人 NKL0 的GMM模型...
# 训练说话人 PLS0 的GMM模型...
# 训练说话人 BCG0 的GMM模型...
# 训练说话人 BSB0 的GMM模型...
# 训练说话人 CXM0 的GMM模型...
# 训练说话人 EJS0 的GMM模型...
# 训练说话人 KDD0 的GMM模型...
# 训练说话人 KRG0 的GMM模型...
# 训练说话人 MEA0 的GMM模型...
# 训练说话人 MLM0 的GMM模型...
# 训练说话人 MPM0 的GMM模型...
# 训练说话人 MWS0 的GMM模型...
# 训练说话人 RDM0 的GMM模型...
# 训练说话人 RLK0 的GMM模型...
# 训练说话人 RRE0 的GMM模型...
# 训练说话人 TCS0 的GMM模型...
# LPCC-GMM模型训练完成!

# %% [markdown]
# ## 5. 评价指标(准确率Accuracy)

# %%
# 5. 评估和分析
def evaluate_gmm_models(gmm_models, test_features_dict):
    """
    评估GMM模型在测试集上的性能
    
    返回:
    true_speakers: 真实说话人ID列表
    pred_speakers: 预测说话人ID列表
    accuracy: 准确率
    """
    true_speakers = []
    pred_speakers = []
    
    for true_speaker, features in test_features_dict.items():
        # 对每个测试样本的每一帧计算对数似然
        scores = {}
        for speaker_id, gmm in gmm_models.items():
            scores[speaker_id] = gmm.score_samples(features).mean()
        
        # 找出似然得分最高的说话人
        predicted_speaker = max(scores, key=scores.get)
        
        # 记录真实标签和预测标签
        true_speakers.append(true_speaker)
        pred_speakers.append(predicted_speaker)
    
    # 计算准确率
    correct = sum(1 for t, p in zip(true_speakers, pred_speakers) if t == p)
    accuracy = correct / len(true_speakers)
    
    return true_speakers, pred_speakers, accuracy

# 评估模型性能
print("评估LPCC-GMM模型性能...")
true_speakers, pred_speakers, accuracy = evaluate_gmm_models(lpcc_gmm_models, test_features_dict)
print(f"LPCC-GMM模型准确率: {accuracy:.4f}")
# Out:
# 评估LPCC-GMM模型性能...
# LPCC-GMM模型准确率: 0.9957

# %% [markdown]
# ##  6. 分析和可视化

# %%
# 可视化混淆矩阵
def plot_confusion_matrix(true_labels, pred_labels):
    """绘制混淆矩阵"""
    # 为每个说话人分配数字ID
    unique_speakers = sorted(set(true_labels).union(set(pred_labels)))
    speaker_to_id = {speaker: i for i, speaker in enumerate(unique_speakers)}
    
    # 转换为数字ID
    true_ids = [speaker_to_id[speaker] for speaker in true_labels]
    pred_ids = [speaker_to_id[speaker] for speaker in pred_labels]
    
    # 计算混淆矩阵
    n_speakers = len(unique_speakers)
    cm = np.zeros((n_speakers, n_speakers))
    
    for t, p in zip(true_ids, pred_ids):
        cm[t, p] += 1
    
    # 创建带有标签的DataFrame
    if n_speakers <= 15:  # 如果说话人数量较少，使用原始标签
        df_cm = pd.DataFrame(cm, index=unique_speakers, columns=unique_speakers)
        title = 'GMM模型混淆矩阵'
    else:  # 对于大量说话人，使用数字索引
        df_cm = pd.DataFrame(cm)
        title = 'GMM模型混淆矩阵 (使用说话人索引)'
    
    # 绘制混淆矩阵
    plt.figure(figsize=(10, 8))
    
    # 如果说话人数量很多，使用更紧凑的热图而不是带注释的版本
    if n_speakers > 40:
        sns.heatmap(df_cm, cmap='Blues')
    else:
        # 对于中等数量的说话人，使用带数值的热图
        sns.heatmap(df_cm, annot=(n_speakers <= 15), fmt='g' if n_speakers <= 15 else '.2f', 
                   cmap='Blues')
    
    plt.xlabel('预测标签')
    plt.ylabel('真实标签')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# 输出分类报告
print("\nGMM模型分类报告:")
print(classification_report(true_speakers, pred_speakers))

# 绘制混淆矩阵
plot_confusion_matrix(true_speakers, pred_speakers)
# Out:
# GMM模型分类报告:
#               precision    recall  f1-score   support
#
#         ABC0       1.00      1.00      1.00         1
#         ADC0       1.00      1.00      1.00         1
#         ADD0       1.00      1.00      1.00         1
#         AEB0       1.00      1.00      1.00         1
#         AEM0       1.00      1.00      1.00         1
#         AEO0       1.00      1.00      1.00         1
#         AFM0       1.00      1.00      1.00         1
#         AJP0       1.00      1.00      1.00         1
#         AJW0       1.00      1.00      1.00         1
#         AKB0       1.00      1.00      1.00         1
#         AKR0       1.00      1.00      1.00         1
#         ALK0       1.00      1.00      1.00         1
#         ALR0       1.00      1.00      1.00         1
#         APB0       1.00      1.00      1.00         1
#         APV0       1.00      1.00      1.00         1
#         ARC0       1.00      1.00      1.00         1
#         ARW0       1.00      1.00      1.00         1
#         BAR0       1.00      1.00      1.00         1
#         BAS0       1.00      1.00      1.00         1
#         BBR0       1.00      1.00      1.00         1
#         BCG0       1.00      1.00      1.00         1
#         BCG1       1.00      1.00      1.00         1
#         BCH0       1.00      1.00      1.00         1
#         BEF0       1.00      1.00      1.00         1
#         BGT0       1.00      1.00      1.00         1
#         BJL0       1.00      1.00      1.00         1
#         BJV0       1.00      1.00      1.00         1
#         BLV0       1.00      1.00      1.00         1
#         BMA0       1.00      1.00      1.00         1
#         BMA1       1.00      1.00      1.00         1
#         BMH0       1.00      1.00      1.00         1
#         BMJ0       1.00      1.00      1.00         1
#         BML0       1.00      1.00      1.00         1
#         BOM0       1.00      1.00      1.00         1
#         BSB0       1.00      1.00      1.00         1
    # 按性别分组计算准确率
    male_indices = [i for i, spk in enumerate(true_speakers) if gender_dict.get(spk) == 'M']
    female_indices = [i for i, spk in enumerate(true_speakers) if gender_dict.get(spk) == 'F']
    
    # 计算每个性别的准确率
    male_accuracy = 0
    if male_indices:
        male_true = [true_speakers[i] for i in male_indices]
        male_pred = [pred_speakers[i] for i in male_indices]
        male_accuracy = np.mean(np.array(male_true) == np.array(male_pred))
    
    female_accuracy = 0
    if female_indices:
        female_true = [true_speakers[i] for i in female_indices]
        female_pred = [pred_speakers[i] for i in female_indices]
        female_accuracy = np.mean(np.array(female_true) == np.array(female_pred))
    
    # 绘制性别对比图
    plt.figure(figsize=(8, 6))
    plt.bar(['男性', '女性'], [male_accuracy, female_accuracy], color=['blue', 'red'], alpha=0.7)
    
    # 添加准确率标签
    plt.text(0, male_accuracy + 0.01, f'{male_accuracy:.4f}', ha='center', fontsize=12)
    plt.text(1, female_accuracy + 0.01, f'{female_accuracy:.4f}', ha='center', fontsize=12)
    
    plt.ylim(0, 1.05)
    plt.ylabel('识别准确率')
    plt.title('GMM模型在不同性别上的识别准确率')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
    
    # 分析性别间的混淆情况
    errors = [(true, pred) for true, pred in zip(true_speakers, pred_speakers) if true != pred]
    
    gender_confusion = {
        'MM': 0,  # 男性识别为男性(但不同人)
        'MF': 0,  # 男性错误识别为女性
        'FM': 0,  # 女性错误识别为男性
        'FF': 0   # 女性识别为女性(但不同人)
    }
    
    for true, pred in errors:
        true_gender = gender_dict.get(true, 'U')
        pred_gender = gender_dict.get(pred, 'U')
        
        if true_gender in 'MF' and pred_gender in 'MF':
            gender_confusion[true_gender + pred_gender] += 1
    
    # 绘制性别混淆饼图
    plt.figure(figsize=(10, 8))
    labels = ['男性→其他男性', '男性→女性', '女性→男性', '女性→其他女性']
    sizes = [gender_confusion['MM'], gender_confusion['MF'], 
             gender_confusion['FM'], gender_confusion['FF']]
    
    # 检查是否有数据
    if sum(sizes) > 0:
        plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, 
                colors=['lightblue', 'lightgreen', 'salmon', 'khaki'])
        plt.axis('equal')
        plt.title('GMM模型性别相关的错误分布')
        plt.tight_layout()
        plt.show()

# 分析性别因素影响
analyze_gender_impact(true_speakers, pred_speakers)

# %%
# 分析方言区域对识别准确率的影响
def analyze_dialect_impact(true_speakers, pred_speakers):
    """分析方言区域对GMM模型性能的影响"""
    # 从说话人文件路径中提取方言区域信息
    dialect_dict = {}
    for speaker in set(true_speakers):
        # 在实际代码中，你需要根据数据结构获取方言信息
        # 这里假设我们已经有这个信息
        for item in test_data:
            if item['speaker_id'] == speaker:
                dialect_dict[speaker] = item['dialect_region']
                break
    
    # 按方言区域分组计算准确率
    dialect_regions = sorted(set(dialect_dict.values()))
    dialect_accuracies = {}
    
    for dialect in dialect_regions:
        dialect_indices = [i for i, spk in enumerate(true_speakers) if dialect_dict.get(spk) == dialect]
        
        if not dialect_indices:
            continue
            
        true_dialect = [true_speakers[i] for i in dialect_indices]
        pred_dialect = [pred_speakers[i] for i in dialect_indices]
        
        accuracy = np.mean(np.array(true_dialect) == np.array(pred_dialect))
        dialect_accuracies[dialect] = accuracy
    
    # 绘制方言区域准确率条形图
    plt.figure(figsize=(12, 6))
    regions = list(dialect_accuracies.keys())
    accuracies = list(dialect_accuracies.values())
    
    plt.bar(regions, accuracies, color='green', alpha=0.7)
    
    # 添加准确率标签
    for i, v in enumerate(accuracies):
        plt.text(i, v + 0.01, f'{v:.4f}', ha='center', fontsize=10)
    
    plt.ylim(0, 1.05)
    plt.xlabel('方言区域')
    plt.ylabel('识别准确率')
    plt.title('GMM模型在不同方言区域的识别准确率')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# 分析方言区域影响
analyze_dialect_impact(true_speakers, pred_speakers)

# %%
# 可视化LPCC特征的分布
def visualize_lpcc_distribution(features_dict):
    """可视化不同说话人的LPCC特征分布"""
    plt.figure(figsize=(12, 8))
    
    # 为了可视化目的，选择前5个说话人和前2个LPCC维度
    speakers = list(features_dict.keys())[:5]
    colors = ['blue', 'red', 'green', 'purple', 'orange']
    
    for i, speaker in enumerate(speakers):
        # 选择每个说话人的部分样本以避免图像过于拥挤
        features = features_dict[speaker]
        if len(features) > 500:
            indices = np.random.choice(len(features), 500, replace=False)
            samples = features[indices]
        else:
            samples = features
        
        # 绘制前两个LPCC维度的散点图
        plt.scatter(samples[:, 0], samples[:, 1], alpha=0.5, color=colors[i], label=speaker)
    
    plt.xlabel('LPCC 1')
    plt.ylabel('LPCC 2')
    plt.title('不同说话人的LPCC特征分布（前两个维度）')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# 可视化LPCC特征分布
visualize_lpcc_distribution(train_features_dict)

# %%
# 使用t-SNE降维可视化高维LPCC特征
def visualize_lpcc_tsne(features_dict, speaker_ids):
    """使用t-SNE降维可视化LPCC特征"""
    from sklearn.manifold import TSNE
    
    # 准备数据
    features = []
    labels = []
    
    # 限制每个说话人的样本数，避免数据不平衡
    samples_per_speaker = 100
    
    for speaker in speaker_ids:
        if speaker not in features_dict:
            continue
            
        speaker_features = features_dict[speaker]
        
        # 如果样本太多，随机选择一部分
        if len(speaker_features) > samples_per_speaker:
            indices = np.random.choice(len(speaker_features), samples_per_speaker, replace=False)
            selected_features = speaker_features[indices]
        else:
            selected_features = speaker_features
        
        features.append(selected_features)
        labels.extend([speaker] * len(selected_features))
    
    # 合并所有特征
    all_features = np.vstack(features)
    
    # 使用t-SNE降维
    tsne = TSNE(n_components=2, random_state=42)
    embedded_features = tsne.fit_transform(all_features)
    
    # 创建唯一标签到索引的映射
    unique_labels = sorted(set(labels))
    label_to_idx = {label: i for i, label in enumerate(unique_labels)}
    
    # 将标签转换为索引
    label_indices = [label_to_idx[label] for label in labels]
    
    # 绘制t-SNE结果
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(embedded_features[:, 0], embedded_features[:, 1], 
                         c=label_indices, cmap='tab10', alpha=0.7)
    
    plt.title('t-SNE可视化LPCC特征空间')
    plt.colorbar(scatter, label='说话人ID')
    plt.tight_layout()
    plt.show()

# 使用t-SNE可视化（选择前8个说话人）
top_speakers = list(train_features_dict.keys())[:8]
visualize_lpcc_tsne(train_features_dict, top_speakers)

# %% [markdown]
# ## 7. 结果讨论
# 讨论你的模型性能，尝试解释为什么某些模型比其他模型表现好，以及可能的改进方法。

# %% [markdown]
# ## 8. 保存模型（可选）
# 如果需要，可以在这里添加代码保存你的模型。
